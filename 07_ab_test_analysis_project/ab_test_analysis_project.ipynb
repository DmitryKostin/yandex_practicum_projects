# %% [markdown]
# # Анализ результатов A/B-теста

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных</a></span><ul class="toc-item"><li><span><a href="#Данные-для-первой-части" data-toc-modified-id="Данные-для-первой-части-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Данные для первой части</a></span></li><li><span><a href="#Данные-для-второй-части" data-toc-modified-id="Данные-для-второй-части-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Данные для второй части</a></span></li></ul></li><li><span><a href="#Загрузка-и-подготовка-данных" data-toc-modified-id="Загрузка-и-подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка и подготовка данных</a></span></li><li><span><a href="#Часть-1.-Приоритизация-гипотез" data-toc-modified-id="Часть-1.-Приоритизация-гипотез-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Часть 1. Приоритизация гипотез</a></span></li><li><span><a href="#Часть-2.-Анализ-A/B-теста" data-toc-modified-id="Часть-2.-Анализ-A/B-теста-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Часть 2. Анализ A/B-теста</a></span><ul class="toc-item"><li><span><a href="#График-кумулятивной-выручки-по-группам" data-toc-modified-id="График-кумулятивной-выручки-по-группам-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>График кумулятивной выручки по группам</a></span></li><li><span><a href="#График-кумулятивного-среднего-чека-по-группам" data-toc-modified-id="График-кумулятивного-среднего-чека-по-группам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>График кумулятивного среднего чека по группам</a></span></li><li><span><a href="#График-относительного-изменения-кумулятивного-среднего-чека" data-toc-modified-id="График-относительного-изменения-кумулятивного-среднего-чека-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>График относительного изменения кумулятивного среднего чека</a></span></li><li><span><a href="#График-кумулятивного-среднего-количества-заказов" data-toc-modified-id="График-кумулятивного-среднего-количества-заказов-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>График кумулятивного среднего количества заказов</a></span></li><li><span><a href="#График-относительного-изменения-кумулятивного-среднего-количества-заказов" data-toc-modified-id="График-относительного-изменения-кумулятивного-среднего-количества-заказов-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>График относительного изменения кумулятивного среднего количества заказов</a></span></li><li><span><a href="#Точечный-график-количества-заказов" data-toc-modified-id="Точечный-график-количества-заказов-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Точечный график количества заказов</a></span></li><li><span><a href="#Расчет-95-го-и-99-го-перцентилей-количества-заказов.-Выбор-границы-для-определения-аномальных-пользователей" data-toc-modified-id="Расчет-95-го-и-99-го-перцентилей-количества-заказов.-Выбор-границы-для-определения-аномальных-пользователей-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Расчет 95-го и 99-го перцентилей количества заказов. Выбор границы для определения аномальных пользователей</a></span></li><li><span><a href="#Точечный-график-стоимостей-заказов" data-toc-modified-id="Точечный-график-стоимостей-заказов-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Точечный график стоимостей заказов</a></span></li><li><span><a href="#Расчет-95-го-и-99-го-перцентилей-стоимости-заказов.-Выбор-границы-для-определения-аномальных-заказов" data-toc-modified-id="Расчет-95-го-и-99-го-перцентилей-стоимости-заказов.-Выбор-границы-для-определения-аномальных-заказов-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Расчет 95-го и 99-го перцентилей стоимости заказов. Выбор границы для определения аномальных заказов</a></span></li><li><span><a href="#Расчет-статистической-значимости-различий-в-среднем-количестве-заказов-между-группами-по-«сырым»-данным" data-toc-modified-id="Расчет-статистической-значимости-различий-в-среднем-количестве-заказов-между-группами-по-«сырым»-данным-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>Расчет статистической значимости различий в среднем количестве заказов между группами по «сырым» данным</a></span></li><li><span><a href="#Расчет-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным" data-toc-modified-id="Расчет-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным-5.11"><span class="toc-item-num">5.11&nbsp;&nbsp;</span>Расчет статистической значимости различий в среднем чеке заказа между группами по «сырым» данным</a></span></li><li><span><a href="#Расчет-статистической-значимости-различий-в-среднем-количестве-заказов-между-группами-по-«очищенным»-данным" data-toc-modified-id="Расчет-статистической-значимости-различий-в-среднем-количестве-заказов-между-группами-по-«очищенным»-данным-5.12"><span class="toc-item-num">5.12&nbsp;&nbsp;</span>Расчет статистической значимости различий в среднем количестве заказов между группами по «очищенным» данным</a></span></li><li><span><a href="#Расчет-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным" data-toc-modified-id="Расчет-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным-5.13"><span class="toc-item-num">5.13&nbsp;&nbsp;</span>Расчет статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным</a></span></li><li><span><a href="#Решение-по-результатам-A/B-теста" data-toc-modified-id="Решение-по-результатам-A/B-теста-5.14"><span class="toc-item-num">5.14&nbsp;&nbsp;</span>Решение по результатам A/B-теста</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Отделом маркетинга крупного интернет-магазина был подготовлен список гипотез для увеличения выручки.
# Выступая в роли аналитика, проведем приоритизацию гипотез, запустим A/B-тест и проанализируем результаты.
#
# Предстоит рассмотреть следующие графики метрик:
# - график кумулятивной выручки по группам;
# - график кумулятивного среднего чека по группам;
# - график относительного изменения кумулятивного среднего чека;
# - график кумулятивного среднего количества заказов по группам;
# - график относительного изменения кумулятивного среднего количества заказов;
# - точечный график количества заказов по пользователям;
# - точечный график стоимостей заказов;
#
# Предстоит решить следующие задачи:
# - посчитать 95-й и 99-й перцентили количества заказов на пользователя и выбрать границу для определения аномальных пользователей;
# - посчитать 95-й и 99-й перцентили стоимости заказов и выбрать границу для определения аномальных заказов;
# - посчитать статистическую значимость различий в среднем количестве заказов между группами по «сырым» данным;
# - посчитать статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным;
# - посчитать статистическую значимость различий в среднем количестве заказов между группами по «очищенным» данным;
# - посчитать статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным;
# - принять решение по результатам теста.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# ### Данные для первой части

# %% [markdown]
# Файл `hypothesis.csv`:
# - `Hypothesis` — краткое описание гипотезы;
# - `Reach` — охват пользователей по 10-балльной шкале;
# - `Impact` — влияние на пользователей по 10-балльной шкале;
# - `Confidence` — уверенность в гипотезе по 10-балльной шкале;
# - `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.

# %% [markdown]
# ### Данные для второй части

# %% [markdown]
# Файл `orders.csv`:
# - `transactionId` — идентификатор заказа;
# - `visitorId` — идентификатор пользователя, совершившего заказ;
# - `date` — дата, когда был совершён заказ;
# - `revenue` — выручка заказа;
# - `group` — группа A/B-теста, в которую попал заказ.
#
# Файл `visitors.csv`:
# - `date` — дата;
# - `group` — группа A/B-теста;
# - `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# ## Загрузка и подготовка данных

# %%
import pandas as pd
import scipy.stats as stats
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Загрузим данные для 1-й части работы.

# %%
hypothesis = pd.read_csv('hypothesis.csv')

# %%
hypothesis.head()
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
#
#    Reach  Impact  Confidence  Efforts
# 0      3      10           8        6
# 1      2       5           4       10
# 2      8       3           7        3
# 3      8       3           3        8
# 4      3       1           1        1

# %% [markdown]
# Загрузим данные для 2-й части работы.

# %%
orders = pd.read_csv('orders.csv')
    
visitors = pd.read_csv('visitors.csv')

# %%
orders.head()
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B

# %%
visitors.head()
# Out:
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756

# %% [markdown]
# Приведем имена столбцов датафрейма `orders` к стандартным названиям для удобства.

# %%
orders.columns = ['orderId', 'userId', 'date', 'revenue', 'group']

# %% [markdown]
# Приведем столбец `date` датафреймов `orders` и `visitors` к нужному формату даты.

# %%
orders['date'] = orders['date'].map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))

visitors['date'] = visitors['date'].map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))

# %% [markdown]
# ## Часть 1. Приоритизация гипотез

# %% [markdown]
# Применим фреймворк ICE для приоритизации гипотез и отсортируем их по убыванию приоритета. Формула фреймворка ICE выглядит следующим образом:

# %% [markdown]
# $$
# ICE = \frac { Impact * Confidence } {Efforts}
# $$

# %%
hypothesis['ICE_score'] = ((hypothesis['Impact'] * hypothesis['Confidence']) / hypothesis['Efforts'])

# %%
(hypothesis
 .sort_values(by='ICE_score', ascending=False)
 .round({'ICE_score': 1})
)
# Out:
#                                                                                                      Hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Самой приоритетной гипотезой исходя из фреймворка ICE является гипотеза "запустить акцию, дающую скидку на товар в день рождения". Гипотеза имеет самый низкий охват (Reach) из всех представленных гипотез - лишь 1. Тем не менее, благодаря высокому эффекту (Impact) и высокой уверенности об оценке (Confidence) данная гипотеза имеет самый высокий ICE score.

# %% [markdown]
# Применим фреймворк RICE для приоритизации гипотез и отсортируем их по убыванию приоритета. Формула фреймворка RICE выглядит следующим образом:

# %% [markdown]
# \begin{equation}
# RICE = \frac { Reach * Impact * Confidence } { Efforts }
# \end{equation}

# %%
hypothesis['RICE_score'] = (hypothesis['Reach'] * hypothesis['Impact'] * hypothesis['Confidence']) / hypothesis['Efforts']

# %%
(hypothesis
 .sort_values(by='RICE_score', ascending=False)
 .round({'ICE_score': 1, 'RICE_score': 1})
)
# Out:
#                                                                                                      Hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# Самой приоритетной гипотезой исходя из фреймворка RICE является гипотеза "добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок". Гипотеза имеет самый высокий охват (Reach) из всех представленных гипотез - 10, то есть нововведение затронет абсолютно всех пользователей - в отличие от предыдущей гипотезы, охват которой составляет лишь 10%. Именно этим объясняется такой высокий RICE score данной гипотезы, даже при том, что обе требуют одинаковых усилий.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Все верно!
# </div>

# %% [markdown]
# ## Часть 2. Анализ A/B-теста

# %% [markdown]
# Перед анализом проверим корректность деления трафика A/B-теста. Посмотрим, сколько уникальных пользователей участвует в A/B-тесте.

# %%
orders['userId'].nunique()
# Out:
# 1031

# %% [markdown]
# Всего в A/B-тесте принимает участие 1031 человек - посмотрим, равны ли пропорции групп в разрезе уникальных пользователей.

# %%
orders.groupby('group').agg({'userId':'nunique'})
# Out:
#        userId
# group
# A         503
# B         586

# %% [markdown]
# Группы A и B не равны между собой - это является одной из значимых ошибок при проведении A/B-теста. Некорректное деление трафика может исказить финальные результаты исследования.

# %% [markdown]
# Посмотрим, сколько уникальных пользователей могло оказаться в обоих группах.

# %%
orders[orders['group'] == 'B'].merge(orders[orders['group'] == 'A'], 
                                     how='inner', 
                                     on='userId')['userId'].nunique()
# Out:
# 58

# %% [markdown]
# 58 человек из 1031 (5.6%) попали в обе группы A/B-теста. Не будем исключать этих пользователей из анализа, поскольку их наличие в целом не отразится на результатах исследования.

# %% [markdown]
# <div class="alert alert-warning">
#     <b>⚠️ Комментарий ревьюера:</b>
#
# Молоджец что сделал такую проверку! Количество пересекающихся пользователей найдено верно. Действительно, удаляь их не стоит, но не из-за того что их мало, а потому что мы не сможем удалить их полностью, они останутся в таблице с посещениями т.к. там нет id пользователей.
# </div>

# %% [markdown]
# ### График кумулятивной выручки по группам

# %% [markdown]
# Построим график кумулятивной выручки по группам.

# %% [markdown]
# Для построения графиков соберем кумулятивные данные. Объявим датафрейм `cumulativeData` со столбцами:
# - `date` — дата;
# - `group` — группа A/B-теста (A или B);
# - `orders` — кумулятивное количество заказов на указанную дату в указанной группе;
# - `buyers` — кумулятивное количество пользователей, совершивших хотя бы один заказ, на указанную дату в указанной группе;
# - `revenue` — кумулятивная выручка на указанную дату в указанной группе (средний чек);
# - `visitors` — кумулятивное количество посетителей интернет-магазина на указанную дату в определённой группе.

# %%
datesGroups = orders[['date','group']].drop_duplicates()

ordersAggregated = datesGroups.apply(
    lambda x: orders[
        np.logical_and(
            orders['date'] <= x['date'], 
            orders['group'] == x['group'])
        ].agg(
            {'date' : 'max', 
             'group' : 'max', 
             'orderId' : 'nunique',
             'userId' : 'nunique', 
             'revenue' : 'sum'}), 
             axis=1).sort_values(by=['date','group'])

visitorsAggregated = datesGroups.apply(
    lambda x: visitors[
        np.logical_and(
            visitors['date'] <= x['date'], 
            visitors['group'] == x['group'])
        ].agg(
            {'date' : 'max', 
             'group' : 'max', 
             'visitors' : 'sum'}), 
             axis=1).sort_values(by=['date','group'])

cumulativeData = ordersAggregated.merge(visitorsAggregated, 
                                        left_on=['date', 'group'], 
                                        right_on=['date', 'group'])

cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

print(cumulativeData.head(5))
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      24      20   148579       719
# 1 2019-08-01     B      21      20   101217       713
# 2 2019-08-02     A      44      38   242401      1338
# 3 2019-08-02     B      45      43   266748      1294
# 4 2019-08-03     A      68      62   354874      1845

# %% [markdown]
# Построим графики кумулятивной выручки по дням и группам A/B-тестирования.

# %%
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]
plt.figure(figsize=(12, 6))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels([format(int(x), ',').replace(',', ' ') for x in current_values])
plt.gca().grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.gca().grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
plt.gca().minorticks_on()
plt.title('Кумулятивная выручка групп A и B')
plt.ylabel('Кумулятивная выручка')
plt.xlabel('Дата')
plt.legend();

# %% [markdown]
# <div class="alert alert-danger">
#     <b>❌ Комментарий ревьюера:</b>
#
# График построен корректно, нужно только его дооформить: подписать оси. А если еще увеличишь размер графика - мой комментарий станет максимально зеленым! 😊
#
# На всякий случай оставлю ссылки на информацию по оформлению графиков matplotlib:
#
# - https://www.python-graph-gallery.com/4-add-title-and-axis-label
# - https://www.python-graph-gallery.com/191-custom-axis-on-matplotlib-chart
#
# Тоже самое нужно сделать и с остальными графиками.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b> Комментарий студента</b>
#
# Скорректировал все графики - подписал оси, увеличил размер, добавил сетку.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера V2:</b>
#
# Супер!
# </div>

# %% [markdown]
# На протяжении всего теста группа B показывает более высокий результат в накоплении выручки. После 17 августа на графике заметен сильный всплеск кумулятивной выручки группы B за очень короткий период - это может быть вызвано наличием сильных выбросов в исходных данных, что значительно искажает всю картину метрики. Проверим, так ли это.

# %%
orders.sort_values(by='revenue', ascending=False).head()
# Out:
#          orderId      userId       date  revenue group
# 425    590470918  1920142716 2019-08-19  1294500     B
# 1196  3936777065  2108080724 2019-08-15   202740     B
# 858    192721366  1316129916 2019-08-27    93940     A
# 1136   666610489  1307669133 2019-08-13    92550     A
# 744   3668308183   888512513 2019-08-27    86620     B

# %% [markdown]
# Как мы видим, в данных действительно присутствуют серьезные выбросы - 19 августа зафиксирован заказ с выручкой в размере 1 294 500 и 15 августа с выручкой в размере 202 740, что является аномальными значениями среди датасета.

# %% [markdown]
# Для корректности анализа удалим два явно аномальных заказа - `orderId` со значениями `590470918` и `3936777065`. Остальные аномалии не будем удалять сейчас - сделаем это после вычисления перцентилей и в конце сравним "сырые" и "очищенные" графики метрик.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Можно и так решить.
# </div>

# %%
orders = orders[(orders['orderId'] != 590470918) & 
                (orders['orderId'] != 3936777065)]

# %% [markdown]
# Перезапишем датафрейм `cumulativeData` и построим график кумулятивной выручки заново.

# %%
datesGroups = orders[['date','group']].drop_duplicates()

ordersAggregated = datesGroups.apply(
    lambda x: orders[
        np.logical_and(
            orders['date'] <= x['date'], 
            orders['group'] == x['group'])
        ].agg(
            {'date' : 'max', 
             'group' : 'max', 
             'orderId' : 'nunique',
             'userId' : 'nunique', 
             'revenue' : 'sum'}), 
             axis=1).sort_values(by=['date','group'])

visitorsAggregated = datesGroups.apply(
    lambda x: visitors[
        np.logical_and(
            visitors['date'] <= x['date'], 
            visitors['group'] == x['group'])
        ].agg(
            {'date' : 'max', 
             'group' : 'max', 
             'visitors' : 'sum'}), 
             axis=1).sort_values(by=['date','group'])

cumulativeData = ordersAggregated.merge(visitorsAggregated, 
                                        left_on=['date', 'group'], 
                                        right_on=['date', 'group'])

cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]
plt.figure(figsize=(12, 6))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels([format(int(x), ',').replace(',', ' ') for x in current_values])
plt.gca().grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.gca().grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
plt.gca().minorticks_on()
plt.title('Кумулятивная выручка групп A и B')
plt.ylabel('Кумулятивная выручка')
plt.xlabel('Дата')
plt.legend();

# %% [markdown]
# График метрики значительно выровнился после удаления всего двух аномальных значений. На протяжении всего теста группа B имеет преимущество над группой A в накоплении суммарной выручки.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Согласен!
# </div>

# %% [markdown]
# ### График кумулятивного среднего чека по группам

# %% [markdown]
# Построим графики среднего чека по группам, разделив кумулятивную выручку на кумулятивное число заказов.

# %%
plt.figure(figsize=(12, 6))
plt.plot(cumulativeRevenueA['date'], 
         cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], 
         cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')

current_values = plt.gca().get_yticks()
plt.gca().grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.gca().grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
plt.gca().minorticks_on()
plt.gca().set_yticklabels([format(int(x), ',').replace(',', ' ') for x in current_values])
plt.title('Кумулятивное среднее чека групп A и B')
plt.ylabel('Кумулятивное среднее чека')
plt.xlabel('Дата')
plt.legend();

# %% [markdown]
# Группа B имела преимущество над группой A в первые 10 дней теста, после чего кумулятивное среднее чека группы A стало выше.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Принято!
# </div>

# %% [markdown]
# ### График относительного изменения кумулятивного среднего чека

# %% [markdown]
# Построим график относительного изменения кумулятивного среднего чека группы B к группе A.

# %%
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, 
                                                   left_on='date', 
                                                   right_on='date', 
                                                   how='left', 
                                                   suffixes=['A', 'B'])
plt.figure(figsize=(12, 6))
plt.plot(mergedCumulativeRevenue['date'], 
         (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)
plt.gca().grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.gca().grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
plt.gca().minorticks_on()
plt.title('Относительное изменение кумулятивного среднего чека группы B к группе A')
plt.ylabel('Процентное отличие группы B от группы А')
plt.xlabel('Дата')
plt.axhline(y=0, color='black', linestyle='--');

# %% [markdown]
# Из данной метрики также видно, что группа B имела преимущество более 30% в начале теста. Однако, группа А показала более уверенные результаты в конце теста.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Согласен!
# </div>

# %% [markdown]
# ### График кумулятивного среднего количества заказов

# %% [markdown]
# Построим график кумулятивного среднего количества заказов по группам.

# %%
cumulativeOrdersA = cumulativeData[cumulativeData['group']=='A'][['date', 'orders']]
cumulativeOrdersB = cumulativeData[cumulativeData['group']=='B'][['date', 'orders']]

plt.figure(figsize=(12, 6))
plt.plot(cumulativeOrdersA['date'], cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeOrdersB['date'], cumulativeRevenueB['orders'], label='B')
plt.gca().grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.gca().grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
plt.gca().minorticks_on()
plt.title('Кумулятивное среднее количества заказов групп A и B')
plt.ylabel('Кумулятивное среднее количества заказов')
plt.xlabel('Дата')
plt.legend();

# %% [markdown]
# Можно утверждать, что группа B суммарно делает большее количество заказов, чем группа A.

# %% [markdown]
# <div class="alert alert-warning">
#     <b>⚠️ Комментарий ревьюера:</b>
#
# Давай дополнительно исследуем конверсию? Отношение количества заказов к посещениям.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b> Комментарий студента</b>
#
# Добавил график кумулятивной конверсии и вывод ниже.
# </div>

# %% [markdown]
# Дополнительно построим график кумулятивной конверсии по группам.

# %%
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

plt.figure(figsize=(12, 6))
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.gca().grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.gca().grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
plt.gca().minorticks_on()
plt.title('Кумулятивная конверсия групп A и B')
plt.ylabel('Кумулятивная конверсия')
plt.xlabel('Дата')
plt.legend();

# %% [markdown]
# Метрика кумулятивной конверсии стабилизировалась во второй половине теста. Группа B показала более высокие значения, чем группа A, закрепившись в среднем на уровне 3.3-3.6%. Группа А закрепилась на уроне 2.9-3.1% с тенденцией к дальнейшему снижению.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера V2:</b>
#
# То, что надо!
# </div>

# %% [markdown]
# ### График относительного изменения кумулятивного среднего количества заказов

# %% [markdown]
# Построим график относительного изменения кумулятивного среднего количества заказов группы B к группе A.

# %%
mergedCumulativeOrders = cumulativeOrdersA.merge(cumulativeOrdersB, 
                                                 left_on='date', 
                                                 right_on='date', 
                                                 how='left', 
                                                 suffixes=['A', 'B'])
plt.figure(figsize=(12, 6))
plt.plot(mergedCumulativeOrders['date'], 
         (mergedCumulativeOrders['ordersB'])/(mergedCumulativeRevenue['ordersA'])-1)
plt.gca().grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.gca().grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
plt.gca().minorticks_on()
plt.title('Относительное изменение кумулятивного среднего количества заказов группы B к группе A')
plt.ylabel('Процентное отличие группы B от группы А')
plt.xlabel('Дата')
plt.axhline(y=0, color='black', linestyle='--');

# %% [markdown]
# Подавляющую часть теста группа B имела в среднем на 15% больше суммарных заказов, чем группа А. Очевидно, что группа B делает намного больше заказов.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Согласен!
# </div>

# %% [markdown]
# ### Точечный график количества заказов

# %% [markdown]
# Построим точечный график количества заказов по пользователям.

# %%
ordersByUsers = (
    orders.groupby('userId', as_index=False)
    .agg({'orderId': 'nunique'}))

ordersByUsers.columns = ['userId', 'orders']

x_values = pd.Series(range(0, len(ordersByUsers)))

plt.figure(figsize=(12, 6))
plt.scatter(x_values, ordersByUsers['orders'])
plt.gca().grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.gca().grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
plt.gca().minorticks_on()
plt.title('Количество заказов по пользователям')
plt.ylabel('Заказы')
plt.xlabel('N-й пользователь');

# %% [markdown]
# Подавляющая доля пользователей совершает не более 1-2 заказов. Гораздо реже количество заказов составляет 3-5. Значения 8-11 заказов предварительно можно охарактеризовать как аномальные.

# %% [markdown]
# ### Расчет 95-го и 99-го перцентилей количества заказов. Выбор границы для определения аномальных пользователей

# %% [markdown]
# Рассчитаем 95-й и 99-й перцентили количества заказов на пользователя и выберем границу для определения аномальных пользователей.

# %%
np.percentile(ordersByUsers['orders'], [95, 99])
# Out:
# array([2., 4.])

# %% [markdown]
# 5% пользователей делает больше 2-х заказов и лишь 1% делает более 4-х заказов. Для дальнейшего анализа в целях точности установим более жесткую границу на уровне 95-го перцентиля - оставим в датасетах покупателей, которые совершают не более 2-х заказов.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Принято!
# </div>

# %% [markdown]
# ### Точечный график стоимостей заказов

# %% [markdown]
# Построим точечный график стоимостей заказов.

# %%
x_values = pd.Series(range(0, len(orders['revenue'])))

plt.figure(figsize=(12, 6))
plt.scatter(x_values, orders['revenue'])
plt.gca().grid(which='major', color='#DDDDDD', linewidth=0.8)
plt.gca().grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
plt.gca().minorticks_on()
plt.title('Стоимость заказов по пользователям')
plt.ylabel('Стоимость заказа')
plt.xlabel('N-й пользователь');

# %% [markdown]
# Как видно из графика, стоимость подавляющей доли заказов не превышает 30 000. Достаточно редко стоимость превышает 60 000.

# %% [markdown]
# ### Расчет 95-го и 99-го перцентилей стоимости заказов. Выбор границы для определения аномальных заказов

# %% [markdown]
# Рассчитаем 95-й и 99-й перцентили стоимости заказов и выберем границу для определения аномальных заказов.

# %%
np.percentile(orders['revenue'], [95, 99])
# Out:
# array([27565. , 56744.2])

# %% [markdown]
# 5% пользователей делает заказы дороже 27 565 и лишь 1% делает их дороже 56 744. Для дальнейшего анализа в целях точности установим более жесткую границу на уровне 95-го перцентиля - оставим в датасетах покупателей, стоимость заказов которых не превышает 27 565.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Принято! Учитывай, что никто не запрещает тебе использовать другие перцентили как пороговые значения (например, 90 или 97).
# </div>

# %% [markdown]
# ### Расчет статистической значимости различий в среднем количестве заказов между группами по «сырым» данным

# %% [markdown]
# Создадим датафрейм `data` со следующими названиями столбцов:
# - `date` — дата;
# - `ordersPerDateA` — количество заказов в выбранную дату в группе A;
# - `revenuePerDateA` — суммарная выручка в выбранную дату в группе A;
# - `ordersPerDateB` — количество заказов в выбранную дату в группе B;
# - `revenuePerDateB` — суммарная выручка в выбранную дату в группе B;
# - `ordersCummulativeA` — суммарное число заказов до выбранной даты включительно в группе A;
# - `revenueCummulativeA` — суммарная выручка до выбранной даты включительно в группе A;
# - `ordersCummulativeB` — суммарное количество заказов до выбранной даты включительно в группе B;
# - `revenueCummulativeB` — суммарная выручка до выбранной даты включительно в группе B;
# - `visitorsPerDateA` — количество пользователей в выбранную дату в группе A;
# - `visitorsPerDateB` — количество пользователей в выбранную дату в группе B;
# - `visitorsCummulativeA` — количество пользователей до выбранной даты включительно в группе A;
# - `visitorsCummulativeB` — количество пользователей до выбранной даты включительно в группе B.

# %%
visitorsADaily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

visitorsBDaily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

ordersADaily = (
    orders[orders['group'] == 'A'][['date', 'orderId', 'userId', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'orderId': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

ordersBDaily = (
    orders[orders['group'] == 'B'][['date', 'orderId', 'userId', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'orderId': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

print(data.head(5))
# Out:
#         date  ordersPerDateA  revenuePerDateA  ordersPerDateB  \
# 0 2019-08-01              24           148579              21
# 1 2019-08-02              20            93822              24
# 2 2019-08-03              24           112473              16
# 3 2019-08-04              16            70825              17
# 4 2019-08-05              25           124218              23
#
#    revenuePerDateB  ordersCummulativeA  revenueCummulativeA  \
# 0           101217                  24               148579
# 1           165531                  44               242401
# 2           114248                  68               354874
# 3           108571                  84               425699
# 4            92428                 109               549917
#
#    ordersCummulativeB  revenueCummulativeB  visitorsPerDateA  \
# 0                  21               101217               719
# 1                  45               266748               619
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <b>⚠️ Комментарий ревьюера:</b>
#
# Построение этой таблицы в целом не требовалось. У тебя уже были все необходимые вычисления.
# </div>

# %% [markdown]
# Разделим пользователей на выборки (по группам A и B), не исключая из данных аномалии.

# %%
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('userId', as_index=False)
    .agg({'orderId': pd.Series.nunique})
)
ordersByUsersA.columns = ['userId', 'orders']

ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('userId', as_index=False)
    .agg({'orderId': pd.Series.nunique})
)
ordersByUsersB.columns = ['userId', 'orders']

sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %% [markdown]
# <p>Введем основную и альтернативные гипотезы:</p>
#
# $\begin{equation*}
#  \begin{cases}
#    H_0 :\text{Средние количества заказов между группами по «сырым» данным не различаются}\\
#    H_1 :\text{Средние количества заказов между группами по «сырым» данным различаются}
#  \end{cases}
# \end{equation*}$
#
# Уровень значимости: $\alpha = 0.05$

# %%
print('Значение p-value:', 
      "{0:.3f}".format(stats.mannwhitneyu(sampleA, sampleB)[1]))
print('Процентное различие между средними выборок:', 
      "{0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# Значение p-value: 0.010
# Процентное различие между средними выборок: 0.135

# %% [markdown]
# Мы получили `p-value = 0.02`, что меньше уровня значимости 0.05. Соответственно, мы можем отклонить нулевую гипотезу в пользу альтернативной - между средними количествами заказов между группами __есть статистически значимое различие__.

# %% [markdown]
# Данное заключение также подтверждается наличием существенной разницы между средними выборок. Среднее группы B на 13.5% больше среднего группы A.

# %% [markdown]
# <div class="alert alert-warning">
#     <b>⚠️ Комментарий ревьюера:</b>
#
# Проверка выполнена верно, давай только подпишем цифры на выходе. Сторонний человек, просматривая твой проект, не поймет что это за цифры и как на основе них ты приняла решение.
#
# То же самое нужно сделать и для других проверок.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b> Комментарий студента</b>
#
# Подписал результаты в каждом статистическом тесте.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера V2:</b>
#
# Спасибо!
# </div>

# %% [markdown]
# ### Расчет статистической значимости различий в среднем чеке заказа между группами по «сырым» данным

# %% [markdown]
# <p>Введем основную и альтернативные гипотезы:</p>
#
# $\begin{equation*}
#  \begin{cases}
#    H_0 :\text{Средние чеки заказов между группами по «сырым» данным не различаются}\\
#    H_1 :\text{Средние чеки заказов между группами по «сырым» данным различаются}
#  \end{cases}
# \end{equation*}$
#
# Уровень значимости: $\alpha = 0.05$

# %%
print('Значение p-value:',
    '{0:.3f}'.format(stats.mannwhitneyu(
    orders[orders['group']=='A']['revenue'], 
    orders[orders['group']=='B']['revenue'])[1]))

print('Процентное различие между средними выборок:',
    '{0:.3f}'.format(
    orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# Значение p-value: 0.400
# Процентное различие между средними выборок: -0.057

# %% [markdown]
# Мы получили `p-value = 0.80`, что выше уровня значимости 0.05. Соответственно, у нас нет оснований отклонить нулевую гипотезу - между средними чеками заказов между группами __нет статистически значимого различия__.

# %% [markdown]
# Между выборками не наблюдается существенной разницы между средними. Среднее группы B на 5.7% меньше среднего группы A.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Принято!
# </div>

# %% [markdown]
# ### Расчет статистической значимости различий в среднем количестве заказов между группами по «очищенным» данным

# %% [markdown]
# В переменной `usersWithManyOrders` запишем пользователей, которые совершили более 2-х заказов (в соответствии с 95-м перцентилем).
#
# В переменной `usersWithExpensiveOrders` запишем пользователей, стоимость заказов которых превышает 27 565 (в соответствии с 95-м перцентилем).
#
# В датафрейме `abnormalUsers` запишем всех пользователей, заказы которых являются аномальными.

# %%
usersWithManyOrders = pd.concat([ordersByUsersA[ordersByUsersA['orders'] > np.percentile(ordersByUsers['orders'], 95)]['userId'],
                                 ordersByUsersB[ordersByUsersB['orders'] > np.percentile(ordersByUsers['orders'], 95)]['userId']],
                                axis=0)

usersWithExpensiveOrders = orders[orders['revenue'] > np.percentile(orders['revenue'], 95)]['userId']

abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
print(abnormalUsers.head(5))
print(abnormalUsers.shape[0])
# Out:
# 568     113298937
# 1099    148427295
# 18      199603092
# 928     204675465
# 23      237748145
# Name: userId, dtype: int64
# 74

# %% [markdown]
# <div class="alert alert-warning">
#   <b>⚠️ Комментарий ревьюера:</b>
#
# Очень не рекомендую вводить руками значения, которые можно получить в результате кода (имею ввиду пороговые значения). По двум причинам:
#
# - когда-нибудь обязательно ошибешься, иначе не бывает
# - код перестанет корректно работать на других входных данных или при копировании кода в другой проект
#
# Лучшим решением вместо цифры подставить под самого перцентиля.
#   </div>

# %% [markdown]
# <div class="alert alert-info">
# <b> Комментарий студента</b>
#
# Заменил цифровые значения в условиях на код вычисления перцентилей.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера V2:</b>
#
# 👍
# </div>

# %% [markdown]
# Как видно после преобразований, число аномальных пользователей - 74. Исключим их из дальнейшего составления выборок.

# %% [markdown]
# Подготовим выборки с "очищенными" данными количества заказов по пользователям из каждой группы теста.

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['userId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['userId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %% [markdown]
# <p>Введем основную и альтернативные гипотезы:</p>
#
# $\begin{equation*}
#  \begin{cases}
#    H_0 :\text{Средние количества заказов между группами по «очищенным» данным не различаются}\\
#    H_1 :\text{Средние количества заказов между группами по «очищенным» данным различаются}
#  \end{cases}
# \end{equation*}$
#
# Уровень значимости: $\alpha = 0.05$

# %%
print('Значение p-value:',
      '{0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('Процентное различие между средними выборок:',
      '{0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# Значение p-value: 0.008
# Процентное различие между средними выборок: 0.169

# %% [markdown]
# Мы получили `p-value = 0.015`, что меньше уровня значимости 0.05. Соответственно, мы можем отклонить нулевую гипотезу в пользу альтернативной - между средними количествами заказов между группами __есть статистически значимое различие__. Очистка данных от выбросов привела к снижению значения p-value - мы можем с большей уверенностью отклонить нулевую гипотезу.

# %% [markdown]
# Разница между средними выборок также выросла с 13.5% по "сырым" данным до 16.9% по "очищенным" данным.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Принято!
# </div>

# %% [markdown]
# ### Расчет статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным

# %% [markdown]
# <p>Введем основную и альтернативные гипотезы:</p>
#
# $\begin{equation*}
#  \begin{cases}
#    H_0 :\text{Средние чеки заказов между группами по «очищенным» данным не различаются}\\
#    H_1 :\text{Средние чеки заказов между группами по «очищенным» данным различаются}
#  \end{cases}
# \end{equation*}$
#
# Уровень значимости: $\alpha = 0.05$

# %%
print('Значение p-value:', 
      '{0:.3f}'.format(
        stats.mannwhitneyu(
            orders[
                np.logical_and(orders['group'] == 'A',
                       np.logical_not(orders['userId'].isin(abnormalUsers)),
                              )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['userId'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)

print('Процентное различие между средними выборок:',
      "{0:.3f}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['userId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['userId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# Значение p-value: 0.332
# Процентное различие между средними выборок: -0.035

# %% [markdown]
# Мы получили `p-value = 0.664`, что выше уровня значимости 0.05. Соответственно, у нас нет оснований отклонить нулевую гипотезу - между средними чеками заказов между группами __нет статистически значимого различия__. Тем не менее, очистка данных от выбросов также поспособствовала снижению значения p-value (по "сырым" данным p-value составил 0.80).

# %% [markdown]
# Разница между средними снизилась с 5.7% без очистки до 3.5% после очистки от выбросов. Среднее группы B на 3.5% меньше среднего группы A.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Принято!
# </div>

# %% [markdown]
# ### Решение по результатам A/B-теста

# %% [markdown]
# Прежде чем принять решение об исходе теста, подведем итоги о всех полученных данных и сравним выводы.

# %% [markdown]
# Исключим из `orders` всех пользователей с выбросами и запишем результат в датафрейм `orders_filtered`.

# %%
orders_filtered = orders[~(orders['userId'].isin(abnormalUsers))]
orders_filtered
# Out:
#          orderId      userId       date  revenue group
# 0     3667963787  3312258926 2019-08-15     1650     B
# 1     2804400009  3642806036 2019-08-15      730     B
# 2     2961555356  4069496402 2019-08-15      400     A
# 3     3797467345  1196621759 2019-08-15     9759     B
# 4     2282983706  2322279887 2019-08-15     2308     B
# ...          ...         ...        ...      ...   ...
# 1190    38478481  1197745035 2019-08-14     8600     B
# 1191  3592955527   608641596 2019-08-14    16490     B
# 1192  2662137336  3733762160 2019-08-14     6490     B
# 1193  2203539145   370388673 2019-08-14     3190     A
# 1194  1807773912   573423106 2019-08-14    10550     A
#
# [1031 rows x 5 columns]

# %% [markdown]
# Запишем датафрейм `cumulativeData_filtered`.

# %%
datesGroups_filtered = orders_filtered[['date','group']].drop_duplicates()

ordersAggregated_filtered = datesGroups_filtered.apply(
    lambda x: orders_filtered[
        np.logical_and(
            orders_filtered['date'] <= x['date'], 
            orders_filtered['group'] == x['group'])
        ].agg(
            {'date' : 'max', 
             'group' : 'max', 
             'orderId' : 'nunique', 
             'userId' : 'nunique', 
             'revenue' : 'sum'}), 
             axis=1).sort_values(by=['date', 'group'])

visitorsAggregated_filtered = datesGroups_filtered.apply(
    lambda x: visitors[
        np.logical_and(
            visitors['date'] <= x['date'], 
            visitors['group'] == x['group'])
        ].agg({'date' : 'max', 
               'group' : 'max', 
               'visitors' : 'sum'}), 
               axis=1).sort_values(by=['date','group'])

cumulativeData_filtered = ordersAggregated_filtered.merge(visitorsAggregated_filtered, 
                                                          left_on=['date', 'group'], 
                                                          right_on=['date', 'group'])

cumulativeData_filtered.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

print(cumulativeData_filtered.head(5))
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      16      15    54351       719
# 1 2019-08-01     B      19      19    78258       713
# 2 2019-08-02     A      35      33   146483      1338
# 3 2019-08-02     B      40      39   171492      1294
# 4 2019-08-03     A      59      57   258956      1845

# %% [markdown]
# Сравним два графика кумулятивной выручки каждой группы - до очистки от выбросов и после.

# %%
fig = plt.figure(figsize=(12, 9))

ax1 = plt.subplot(2, 2, 1)
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

ax1.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')
ax1.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')
ax1.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax1.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
ax1.minorticks_on()
plt.ylabel('Кумулятивная выручка')
plt.xlabel('Дата')
plt.xticks(rotation=30)

plt.title('До удаления аномалий («сырые» данные)')
ax1.legend()

ax2 = plt.subplot(2, 2, 2, sharey = ax1)
cumulativeRevenueA_filtered = cumulativeData_filtered[cumulativeData_filtered['group']=='A'][['date','revenue', 'orders']]
cumulativeRevenueB_filtered = cumulativeData_filtered[cumulativeData_filtered['group']=='B'][['date','revenue', 'orders']]

ax2.plot(cumulativeRevenueA_filtered['date'], cumulativeRevenueA_filtered['revenue'], label='A')
ax2.plot(cumulativeRevenueB_filtered['date'], cumulativeRevenueB_filtered['revenue'], label='B')
ax2.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax2.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
ax2.minorticks_on()
plt.ylabel('Кумулятивная выручка')
plt.xlabel('Дата')
plt.title('После удаления аномалий («очищенные» данные)')
ax2.legend()
plt.xticks(rotation=30)

ax2.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',').replace(',', ' ')))
fig.suptitle("Кумулятивная выручка групп A и B", verticalalignment='baseline', y=0.97, fontsize=14)
plt.tight_layout()

plt.show()

# %% [markdown]
# После очистки от выбросов уровни выручки обеих групп снизились - на обоих графиках по-прежнему заметно преобладание группы B.

# %% [markdown]
# Далее, рассмотрим графики кумулятивного среднего чека группа А и B.

# %%
fig = plt.figure(figsize=(12, 9))

ax1 = plt.subplot(2, 2, 1)
ax1.plot(cumulativeRevenueA['date'], 
         cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
ax1.plot(cumulativeRevenueB['date'], 
         cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')
ax1.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax1.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
ax1.minorticks_on()
plt.ylabel('Кумулятивное среднее чека')
plt.xlabel('Дата')
plt.title('До удаления аномалий («сырые» данные)')
plt.xticks(rotation=30)
plt.legend()

ax2 = plt.subplot(2, 2, 2, sharey = ax1)
ax2.plot(cumulativeRevenueA_filtered['date'], 
         cumulativeRevenueA_filtered['revenue']/cumulativeRevenueA_filtered['orders'], label='A')
ax2.plot(cumulativeRevenueB_filtered['date'], 
         cumulativeRevenueB_filtered['revenue']/cumulativeRevenueB_filtered['orders'], label='B')
ax2.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax2.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
ax2.minorticks_on()
plt.ylabel('Кумулятивное среднее чека')
plt.xlabel('Дата')
plt.xticks(rotation=30)
fig.suptitle('Кумулятивное среднее чека групп A и B', 
             verticalalignment='baseline', 
             y=0.97, fontsize=14)
plt.tight_layout()
plt.title('После удаления аномалий («очищенные» данные)')
ax2.legend();

# %% [markdown]
# Уровни кумулятивных средних существенно снизились, в целом сохраняя прежнюю динамику. После очистки от выбросов обе группы зафиксировались на уровне 5 000. В данной метрике группа А закончила тест с небольшим опережением.

# %%
mergedCumulativeRevenue_filtered = cumulativeRevenueA_filtered.merge(cumulativeRevenueB_filtered, 
                                                   left_on='date', 
                                                   right_on='date', 
                                                   how='left', 
                                                   suffixes=['A', 'B'])

fig = plt.figure(figsize=(12, 9))

ax1 = plt.subplot(2, 2, 1)
ax1.plot(mergedCumulativeRevenue['date'], 
         (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)
ax1.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax1.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
ax1.minorticks_on()
plt.xticks(rotation=30)
plt.ylabel('Процентное отличие группы B от группы А')
plt.xlabel('Дата')
plt.title('До удаления аномалий («сырые» данные)')
plt.axhline(y=0, color='black', linestyle='--');

ax2 = plt.subplot(2, 2, 2, sharey = ax1)
ax2.plot(mergedCumulativeRevenue_filtered['date'], 
         (mergedCumulativeRevenue_filtered['revenueB']/mergedCumulativeRevenue_filtered['ordersB'])/(mergedCumulativeRevenue_filtered['revenueA']/mergedCumulativeRevenue_filtered['ordersA'])-1)
ax2.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax2.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
ax2.minorticks_on()
plt.xticks(rotation=30)
plt.ylabel('Процентное отличие группы B от группы А')
plt.xlabel('Дата')
plt.title('После удаления аномалий («очищенные» данные)')
fig.suptitle('Относительное изменение кумулятивного среднего чека группы B к группе A', 
             verticalalignment='baseline', y=0.97, fontsize=14)
plt.tight_layout()
plt.axhline(y=0, color='black', linestyle='--');

# %% [markdown]
# График относительного изменения кумулятивного среднего чека сохранил в целом аналогичную динамику после очистки от выбросов, показывая более выраженное преимущество группы А в разрезе данной метрики.

# %%
fig = plt.figure(figsize=(12, 9))

ax1 = plt.subplot(2, 2, 1)
cumulativeOrdersA = cumulativeData[cumulativeData['group']=='A'][['date', 'orders']]
cumulativeOrdersB = cumulativeData[cumulativeData['group']=='B'][['date', 'orders']]

ax1.plot(cumulativeOrdersA['date'], cumulativeRevenueA['orders'], label='A')
ax1.plot(cumulativeOrdersB['date'], cumulativeRevenueB['orders'], label='B')
ax1.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax1.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
ax1.minorticks_on()
plt.ylabel('Кумулятивное среднее количества заказов')
plt.xlabel('Дата')
plt.title('До удаления аномалий («сырые» данные)')
plt.xticks(rotation=30)
plt.legend();

ax2 = plt.subplot(2, 2, 2, sharey = ax1)
cumulativeOrdersA_filtered = cumulativeData_filtered[cumulativeData_filtered['group']=='A'][['date', 'orders']]
cumulativeOrdersB_filtered = cumulativeData_filtered[cumulativeData_filtered['group']=='B'][['date', 'orders']]

ax2.plot(cumulativeOrdersA_filtered['date'], cumulativeRevenueA_filtered['orders'], label='A')
ax2.plot(cumulativeOrdersB_filtered['date'], cumulativeRevenueB_filtered['orders'], label='B')
ax2.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax2.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
ax2.minorticks_on()
plt.ylabel('Кумулятивное среднее количества заказов')
plt.xlabel('Дата')
plt.title('После удаления аномалий («очищенные» данные)')
plt.xticks(rotation=30)
fig.suptitle('Кумулятивное среднее количества заказов групп A и B', 
             verticalalignment='baseline', y=0.97, fontsize=14)
plt.tight_layout()
plt.legend();

# %% [markdown]
# После очистки от выбросов график незначительно снизил свой уровень, показывая очевидное преимущество группы B.

# %%
mergedCumulativeOrders_filtered = cumulativeOrdersA_filtered.merge(cumulativeOrdersB_filtered, 
                                                 left_on='date', 
                                                 right_on='date', 
                                                 how='left', 
                                                 suffixes=['A', 'B'])

fig = plt.figure(figsize=(12, 9))

ax1 = plt.subplot(2, 2, 1)
ax1.plot(mergedCumulativeOrders['date'], 
         (mergedCumulativeOrders['ordersB'])/(mergedCumulativeRevenue['ordersA'])-1)
ax1.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax1.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
ax1.minorticks_on()
plt.xticks(rotation=30)
plt.ylabel('Процентное отличие группы B от группы А')
plt.xlabel('Дата')
plt.title('До удаления аномалий («сырые» данные)')
plt.axhline(y=0, color='black', linestyle='--')

ax2 = plt.subplot(2, 2, 2, sharey = ax1)
ax2.plot(mergedCumulativeOrders_filtered['date'], 
         (mergedCumulativeOrders_filtered['ordersB'])/(mergedCumulativeRevenue_filtered['ordersA'])-1)
ax2.grid(which='major', color='#DDDDDD', linewidth=0.8)
ax2.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=1)
ax2.minorticks_on()
plt.xticks(rotation=30)
plt.ylabel('Процентное отличие группы B от группы А')
plt.xlabel('Дата')
plt.title('После удаления аномалий («очищенные» данные)')
fig.suptitle('Относительное изменение кумулятивного среднего количества заказов группы B к группе A', 
             verticalalignment='baseline', y=0.97, fontsize=14)
plt.tight_layout()
plt.axhline(y=0, color='black', linestyle='--');

# %% [markdown]
# После очистки от выбросов график сохранил общую динамику, показывая очевидное преимущество группы B в среднем на уровне 15-20%. Это подтверждает тот факт, что группа B в течение теста была склонна делать больше заказов, чем группа А.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера V2:</b>
#
# Эта часть проекта максимально убедительна! 👏
# </div>

# %% [markdown]
# Подводя итоги исследования, можно зафиксировать следующие факты:
# - есть статистически значимое различие по среднему количеству заказов между группами как по «сырым» (`p-value = 0.02`), так и по данным после фильтрации аномалий (`p-value = 0.015`);
# - нет статистически значимого различия по среднему чеку между группами ни по «сырым» (`p-value = 0.80`), ни по данным после фильтрации аномалий (`p-value = 0.664`);
# - график относительного изменения кумулятивного среднего чека между группами сообщает, что результаты группы B на 5-7% хуже группы A по окончанию теста;
# - график относительного изменения кумулятивного среднего количества заказов говорит о том, что подавляющую часть теста группа B имела в среднем на 15% больше суммарных заказов, чем группа А;
# - на графике кумулятивной выручки заметно преобладание группы B как по «сырым» данным, так и по данным после фильтрации аномалий;
# - на графике кумулятивного среднего чека нет особой разницы между группами как по «сырым» данным, так и по данным после фильтрации аномалий, тем не менее, группа А закончила тест с небольшим опережением.

# %% [markdown]
# Исходя из обнаруженных фактов, тест следует __остановить, признав его успешным и зафиксировав победу группы B.__

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера:</b>
#
# Все верно!
# </div>

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе данного исследования были построены графики следующих метрик:
# - график кумулятивной выручки по группам;
# - график кумулятивного среднего чека по группам;
# - график относительного изменения кумулятивного среднего чека;
# - график кумулятивного среднего количества заказов по группам;
# - график относительного изменения кумулятивного среднего количества заказов;
# - точечный график количества заказов по пользователям;
# - точечный график стоимостей заказов.
#
# Также, в ходе исследования были решены следующие задачи:
# - посчитаны 95-й и 99-й перцентили количества заказов на пользователя и выбрать границу для определения аномальных пользователей;
# - посчитаны 95-й и 99-й перцентили стоимости заказов и выбрать границу для определения аномальных заказов;
# - посчитаны статистическую значимость различий в среднем количестве заказов между группами по «сырым» данным;
# - посчитаны статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным;
# - посчитаны статистическую значимость различий в среднем количестве заказов между группами по «очищенным» данным;
# - посчитаны статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным;
# - было принято решение об успешном завершении A/B-теста и о признании победы группы B над группой А по ряду метрик.

# %% [markdown]
# Решение о завершении теста и победе группы B было принято на основании следующих фактов:
# - есть статистически значимое различие по среднему количеству заказов между группами как по «сырым» (`p-value = 0.02`), так и по данным после фильтрации аномалий (`p-value = 0.015`);
# - нет статистически значимого различия по среднему чеку между группами ни по «сырым» (`p-value = 0.80`), ни по данным после фильтрации аномалий (`p-value = 0.664`);
# - график относительного изменения кумулятивного среднего чека между группами сообщает, что результаты группы B на 5-7% хуже группы A по окончанию теста;
# - график относительного изменения кумулятивного среднего количества заказов говорит о том, что подавляющую часть теста группа B имела в среднем на 15% больше суммарных заказов, чем группа А;
# - на графике кумулятивной выручки заметно преобладание группы B как по «сырым» данным, так и по данным после фильтрации аномалий;
# - на графике кумулятивного среднего чека нет особой разницы между группами как по «сырым» данным, так и по данным после фильтрации аномалий, тем не менее, группа А закончила тест с небольшим опережением.

# %% [markdown]
# <div class="alert alert-success">
#     <b>✅ Комментарий ревьюера V2:</b>
#
# Проект принят! 🎉
#
# Спасибо за отличный проект, Дмитрий!
# </div>
